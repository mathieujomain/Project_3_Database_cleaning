# %% [markdown]
# Weekly project 3: Data cleaning

# %%
#First step import usefull library
import pandas as pd
import numpy as np

# %%
#Import data using pandas
df=pd.read_excel(r"C:\Users\matui\Downloads\2 -Entrepreneurial competency in university students.xlsx")
df
# Out:
#           EducationSector Target IndividualProject    Age  Gender     City  \
# 0    Engineering Sciences                        No  19.0    Male      Yes
# 1    Engineering Sciences                       Yes  22.0    Male       No
# 2    Engineering Sciences                        No  18.0    Male      Yes
# 3    Engineering Sciences                       Yes  20.0    Male      Yes
# 4    Engineering Sciences                       Yes  19.0    Male      Yes
# ..                    ...                       ...   ...     ...      ...
# 214  Engineering Sciences                       Yes  19.0    Male      Yes
# 215  Engineering Sciences                       Yes  19.0    Male      Yes
# 216  Engineering Sciences                       Yes  22.0  Female      Yes
# 217  Engineering Sciences                        No  19.0    male      Yes
# 218  Engineering Sciences                       Yes  18.0    Male  unknown
#
# ...

# %%
#Checking every column data types
df.dtypes
# Out:
# EducationSector               object
# Target IndividualProject      object
# Age                          float64
# Gender                        object
# City                          object
# Influenced                    object
# Perseverance                 float64
# DesireToTakeInitiative       float64
# Competitiveness              float64
# SelfReliance                 float64
# StrongNeedToAchieve          float64
# SelfConfidence               float64
# GoodPhysicalHealth           float64
# MentalDisorder                object
# KeyTraits                     object
# ReasonsForLack                object
# Target-ent_competency          int64
# dtype: object

# %%
#Checking columns names
df.columns
# Out:
# Index(['EducationSector', 'Target IndividualProject ', 'Age', 'Gender', 'City',
#        'Influenced', 'Perseverance', 'DesireToTakeInitiative',
#        'Competitiveness', 'SelfReliance', 'StrongNeedToAchieve',
#        'SelfConfidence', 'GoodPhysicalHealth', 'MentalDisorder', 'KeyTraits',
#        'ReasonsForLack', 'Target-ent_competency'],
#       dtype='object')

# %%
#Checking values in column KeyTraits (we saw with the first df that values might need some cleaning)
df['KeyTraits'].value_counts()
# Out:
# Positivity      73
# Passion         61
# Work Ethic      39
# Vision          35
# Resilience       9
# Rrresilience     1
# passion          1
# Name: KeyTraits, dtype: int64

# %%
df['KeyTraits'] = df['KeyTraits'].str.lower()

# %%
#Replace the misspelled value to the correct version
df.loc[df['KeyTraits'].str.startswith('rr'), 'KeyTraits'] = 'resilience'

# %%
#Checking missing values
df.isna().sum()
# Out:
# EducationSector               0
# Target IndividualProject      0
# Age                          14
# Gender                        0
# City                          0
# Influenced                    0
# Perseverance                 17
# DesireToTakeInitiative       11
# Competitiveness               9
# SelfReliance                 22
# StrongNeedToAchieve           8
# SelfConfidence                7
# GoodPhysicalHealth            7
# MentalDisorder               12
# KeyTraits                     0
# ReasonsForLack               91
# Target-ent_competency         0
# dtype: int64

# %%
#Checking wrong values in City
df['City'].value_counts()
# Out:
# Yes        182
# No          33
# unknown      3
# no           1
# Name: City, dtype: int64

# %%
#Replace the misspelled value to the correct version
df.loc[df['City'].str.startswith('no'), 'City'] = 'No'
df.loc[df['City'].str.startswith('unk'), 'City'] = np.nan

# %%
#Replace missing ages by the mean
df.loc[(df['Age'].isnull()), 'Age'] = 20

# %%
#Replace missing values by NaN
df.loc[(df['MentalDisorder'].isnull()), 'MentalDisorder'] = "no_value"
df.loc[df['MentalDisorder'].str.startswith('no_value'), 'MentalDisorder'] = np.nan

# %%
#Checking indicator mean value
df.describe()
# Out:
#               Age  Perseverance  DesireToTakeInitiative  Competitiveness  \
# count  219.000000    202.000000              208.000000       210.000000
# mean    19.771689      3.346535                3.591346         3.571429
# std      1.282530      1.001845                1.163587         1.118416
# min     17.000000      1.000000                1.000000         1.000000
# 25%     19.000000      3.000000                3.000000         3.000000
# 50%     20.000000      3.000000                4.000000         4.000000
# 75%     20.000000      4.000000                5.000000         4.000000
# max     26.000000      5.000000                5.000000         5.000000
#
#        SelfReliance  StrongNeedToAchieve  SelfConfidence  GoodPhysicalHealth  \
# count    197.000000           211.000000      212.000000          212.000000
# mean       3.705584             3.914692        3.566038            3.566038
# std        1.066474             1.033866        1.122952            1.105941
# ...

# %%
#Creating a function that will replace the missing values by the mean
def fill_indicator(column, mean):

        df.loc[(df[column].isnull()), column] = mean

# %%
#Creating dictionnary with the pair column : mean
value = {'Perseverance':3,'DesireToTakeInitiative':3,
        'Competitiveness':4, 'SelfReliance':4, 'StrongNeedToAchieve':4,
        'SelfConfidence':3, 'GoodPhysicalHealth':3}

# %%
#Loop to use the function fill_indicator with values in the dictionnary
for i in value:
    fill_indicator(i, value[i])

# %%
#Checking content of Reasons for lack
df['ReasonsForLack'].value_counts()
# Out:
# Just not interested! (Want to work in the corporate sector, or for the government or pursue research or something else)                                                                                                                                                                                                                     41
# Academic Pressure                                                                                                                                                                                                                                                                                                                           11
# ...

# %%
#Delete the column reasons because half of value are missing
del df['ReasonsForLack']

# %%
#Checking again missing values (city and mental disorder should have some)
df.isna().sum()
# Out:
# EducationSector               0
# Target IndividualProject      0
# Age                           0
# Gender                        0
# City                          3
# Influenced                    0
# Perseverance                  0
# DesireToTakeInitiative        0
# Competitiveness               0
# SelfReliance                  0
# StrongNeedToAchieve           0
# SelfConfidence                0
# GoodPhysicalHealth            0
# MentalDisorder               12
# KeyTraits                     0
# Target-ent_competency         0
# dtype: int64

# %%
df
# Out:
#           EducationSector Target IndividualProject    Age  Gender City  \
# 0    Engineering Sciences                        No  19.0    Male  Yes
# 1    Engineering Sciences                       Yes  22.0    Male   No
# 2    Engineering Sciences                        No  18.0    Male  Yes
# 3    Engineering Sciences                       Yes  20.0    Male  Yes
# 4    Engineering Sciences                       Yes  19.0    Male  Yes
# ..                    ...                       ...   ...     ...  ...
# 214  Engineering Sciences                       Yes  19.0    Male  Yes
# 215  Engineering Sciences                       Yes  19.0    Male  Yes
# 216  Engineering Sciences                       Yes  22.0  Female  Yes
# 217  Engineering Sciences                        No  19.0    male  Yes
# 218  Engineering Sciences                       Yes  18.0    Male  NaN
#
#     Influenced  Perseverance  DesireToTakeInitiative  Competitiveness  \
# ...

# %%
#Exporting the DataFrame to csv
df.to_csv(r'C:\Users\matui\Downloads\project_3_db.csv', index=False)

# %% [markdown]
# --------------

# %% [markdown]
# Sql alchemy

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector as sql

# %%
conn = sql.connect(host = "localhost",
                   user = "root",
                   password = "007m008Mat!",
                   database = "project_3")

# %%
import sqlalchemy as db

# %%
query = db.select([db.func.count(data.columns.age)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17376/806148979.py in <module>
# ----> 1 query = db.select([db.func.count(data.columns.age)])
#
# NameError: name 'data' is not defined
